# %%
import pandas as pd

# %%
data=pd.read_csv('train.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.PassengerId.dtypes
# Out:
# dtype('int64')

# %% [markdown]
# slicing

# %%
data[['PassengerId']]
# Out:
#      PassengerId
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
# ..           ...
# 886          887
# 887          888
# 888          889
# 889          890
# 890          891
#
# [891 rows x 1 columns]

# %%
data1=data[['Name','PassengerId']][0:10]

# %%
data1
# Out:
#                                                 Name  PassengerId
# 0                            Braund, Mr. Owen Harris            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2
# 2                             Heikkinen, Miss. Laina            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)            4
# 4                           Allen, Mr. William Henry            5
# 5                                   Moran, Mr. James            6
# 6                            McCarthy, Mr. Timothy J            7
# 7                     Palsson, Master. Gosta Leonard            8
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)            9
# 9                Nasser, Mrs. Nicholas (Adele Achem)           10

# %%
data.loc[20:35:2,['Cabin','PassengerId']]
# Out:
#    Cabin  PassengerId
# 20   NaN           21
# 22   NaN           23
# 24   NaN           25
# 26   NaN           27
# 28   NaN           29
# 30   NaN           31
# 32   NaN           33
# 34   NaN           35

# %%
data3=data.loc[1:9:2,['Cabin','PassengerId']]

# %%
data3
# Out:
#   Cabin  PassengerId
# 1   C85            2
# 3  C123            4
# 5   NaN            6
# 7   NaN            8
# 9   NaN           10

# %% [markdown]
# sort

# %%
data3.sort_values(by='Cabin')
# Out:
#   Cabin  PassengerId
# 3  C123            4
# 1   C85            2
# 5   NaN            6
# 7   NaN            8
# 9   NaN           10

# %%
data4=data3.sort_values(by='Cabin',ascending=False)

# %%
data4
# Out:
#   Cabin  PassengerId
# 1   C85            2
# 3  C123            4
# 5   NaN            6
# 7   NaN            8
# 9   NaN           10

# %% [markdown]
# updating columns

# %%
data4['PassengerId']=data4['PassengerId']-1

# %%
data4
# Out:
#   Cabin  PassengerId
# 1   C85            1
# 3  C123            3
# 5   NaN            5
# 7   NaN            7
# 9   NaN            9

# %% [markdown]
# describe

# %%
data4.describe()
# Out:
#        PassengerId
# count     5.000000
# mean      5.000000
# std       3.162278
# min       1.000000
# 25%       3.000000
# 50%       5.000000
# 75%       7.000000
# max       9.000000

# %% [markdown]
# slicing with iloc

# %%
data.iloc[:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
data.iloc[:4,:3]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1

# %%
data.iloc[:4,-1]
# Out:
# 0    S
# 1    C
# 2    S
# 3    S
# Name: Embarked, dtype: object

# %%
data5=data.iloc[0:10:2,[1,4]]

# %%
data5
# Out:
#    Survived     Sex
# 0         0    male
# 2         1  female
# 4         0    male
# 6         0    male
# 8         1  female

# %%
data5.Sex
# Out:
# 0      male
# 2    female
# 4      male
# 6      male
# 8    female
# Name: Sex, dtype: object

# %%
data5.loc[0:,['Sex']]
# Out:
#       Sex
# 0    male
# 2  female
# 4    male
# 6    male
# 8  female

# %%
data5[['Sex']]
# Out:
#       Sex
# 0    male
# 2  female
# 4    male
# 6    male
# 8  female

# %%
data5.iloc[:,[0]]
# Out:
#    Survived
# 0         0
# 2         1
# 4         0
# 6         0
# 8         1

# %%
data5.iloc[:,[0]].sum()
# Out:
# Survived    2
# dtype: int64

# %%
data5.iloc[:,[0]].max()
# Out:
# Survived    1
# dtype: int64

# %%
data5.Sex.max()
# Out:
# 'male'

# %%
data5.loc[:,['Sex']].min()
# Out:
# Sex    female
# dtype: object

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data[['Pclass']].count()
# Out:
# Pclass    891
# dtype: int64

# %%
data5
# Out:
#    Survived     Sex
# 0         0    male
# 2         1  female
# 4         0    male
# 6         0    male
# 8         1  female

# %%
data6=data[['Fare','PassengerId']][0:10]

# %%
data6
# Out:
#       Fare  PassengerId
# 0   7.2500            1
# 1  71.2833            2
# 2   7.9250            3
# 3  53.1000            4
# 4   8.0500            5
# 5   8.4583            6
# 6  51.8625            7
# 7  21.0750            8
# 8  11.1333            9
# 9  30.0708           10

# %% [markdown]
# boolean indexing

# %%
data6.Fare>40
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# 9    False
# Name: Fare, dtype: bool

# %%
data6[data6.Fare>50]
# Out:
#       Fare  PassengerId
# 1  71.2833            2
# 3  53.1000            4
# 6  51.8625            7

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data6
# Out:
#       Fare  PassengerId
# 0   7.2500            1
# 1  71.2833            2
# 2   7.9250            3
# 3  53.1000            4
# 4   8.0500            5
# 5   8.4583            6
# 6  51.8625            7
# 7  21.0750            8
# 8  11.1333            9
# 9  30.0708           10

# %%
data7=data[data.Fare>30]

# %%
data8=data7[data7.Fare<80]

# %%
data8
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 9             10         1       2
# 13            14         0       3
# ..           ...       ...     ...
# 850          851         0       3
# 853          854         1       1
# 863          864         0       3
# 867          868         0       1
# 871          872         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data8.Embarked.unique()
# Out:
# array(['C', 'S'], dtype=object)

# %%
data8.Embarked=='S'
# Out:
# 1      False
# 3       True
# 6       True
# 9      False
# 13      True
#        ...
# 850     True
# 853     True
# 863     True
# 867     True
# 871     True
# Name: Embarked, Length: 158, dtype: bool

# %%
data9=data8[data8.Embarked=='S']

# %%
data9
# Out:
#      PassengerId  Survived  Pclass  \
# 3              4         1       1
# 6              7         0       1
# 13            14         0       3
# 23            24         1       1
# 25            26         1       3
# ..           ...       ...     ...
# 850          851         0       3
# 853          854         1       1
# 863          864         0       3
# 867          868         0       1
# 871          872         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data9.iloc[:,1].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
data9.groupby(['PassengerId']).min()
# Out:
#              Survived  Pclass  \
# PassengerId
# 4                   1       1
# 7                   0       1
# 14                  0       3
# 24                  1       1
# 26                  1       3
# ...               ...     ...
# 851                 0       3
# 854                 1       1
# 864                 0       3
# 868                 0       1
# 872                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 14                                 Andersson, Mr. Anders Johan    male  39.0
# 24                                Sloper, Mr. William Thompson    male  28.0
# 26           Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0
# ...                                                        ...     ...   ...
# ...

# %%
data9[data9.Survived==0]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 6              7         0       1                  McCarthy, Mr. Timothy J
# 13            14         0       3              Andersson, Mr. Anders Johan
# 35            36         0       1           Holverson, Mr. Alexander Oskar
# 50            51         0       3               Panula, Master. Juha Niilo
# 59            60         0       3       Goodwin, Master. William Frederick
# ..           ...       ...     ...                                      ...
# 846          847         0       3                 Sage, Mr. Douglas Bullen
# 848          849         0       2                        Harper, Rev. John
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 863          864         0       3        Sage, Miss. Dorothy Edith "Dolly"
# 867          868         0       1     Roebling, Mr. Washington Augustus II
#
# ...
